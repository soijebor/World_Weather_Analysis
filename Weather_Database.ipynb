# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Import the random module.
import random

# Import timeit.
import timeit

# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 613

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=9077f397cb8a1391689922c8104c8fff

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i in range(len(cities)):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + "i"

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        try:
            city_rain = city_weather["rain"]["1h"] 
        except:
            city_rain = 0
        pass
        
        try:
            city_snow = city_weather["snow"]["1h"]
        except:
            city_snow = 0
        pass

        city_description = city_weather["weather"][0]["description"]

        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Rain(inches)": city_rain,
                          "Snow(inches)": city_snow,
                          "Current Description": city_description})

    # If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 13 | leeton
# Processing Record 2 of Set 13 | port elizabeth
# Processing Record 3 of Set 13 | nouadhibou
# Processing Record 4 of Set 13 | severnoye
# Processing Record 5 of Set 13 | busselton
# Processing Record 6 of Set 13 | sorong
# Processing Record 7 of Set 13 | kruisfontein
# Processing Record 8 of Set 13 | matara
# Processing Record 9 of Set 13 | kindu
# Processing Record 10 of Set 13 | albany
# Processing Record 11 of Set 13 | kracheh
# City not found. Skipping...
# Processing Record 12 of Set 13 | pryazha
# Processing Record 13 of Set 13 | bambous virieux
# Processing Record 14 of Set 13 | cape town
# Processing Record 15 of Set 13 | sorland
# Processing Record 16 of Set 13 | caohai
# Processing Record 17 of Set 13 | mataura
# Processing Record 18 of Set 13 | adrar
# Processing Record 19 of Set 13 | bluff
# Processing Record 20 of Set 13 | kapaa
# Processing Record 21 of Set 13 | mumford
# Processing Record 22 of Set 13 | ushuaia
# Processing Record 23 of Set 13 | khatanga
# Processing Record 24 of Set 13 | punta arenas
# Processing Record 25 of Set 13 | qaanaaq
# Processing Record 26 of Set 13 | mar del plata
# Processing Record 27 of Set 13 | taolanaro
# City not found. Skipping...
# Processing Record 28 of Set 13 | loa janan
# Processing Record 29 of Set 13 | rikitea
# Processing Record 30 of Set 13 | gizo
# Processing Record 31 of Set 13 | port alfred
# Processing Record 32 of Set 13 | inhambane
# Processing Record 33 of Set 13 | keningau
# Processing Record 34 of Set 13 | vaini
# Processing Record 35 of Set 13 | pauini
# Processing Record 36 of Set 13 | atuona
# Processing Record 37 of Set 13 | new norfolk
# Processing Record 38 of Set 13 | formosa do rio preto
# Processing Record 39 of Set 13 | hithadhoo
# Processing Record 40 of Set 13 | bethel
# Processing Record 41 of Set 13 | clyde river
# Processing Record 42 of Set 13 | kuche
# City not found. Skipping...
# Processing Record 43 of Set 13 | bengkulu
# Processing Record 44 of Set 13 | lasa
# Processing Record 45 of Set 13 | terrace
# Processing Record 46 of Set 13 | pisco
# Processing Record 47 of Set 13 | kirakira
# Processing Record 48 of Set 13 | hermanus
# Processing Record 49 of Set 13 | pacific grove
# Processing Record 50 of Set 13 | talnakh
# Processing Record 1 of Set 14 | japura
# Processing Record 2 of Set 14 | dikson
# Processing Record 3 of Set 14 | hasaki
# Processing Record 4 of Set 14 | valparaiso
# Processing Record 5 of Set 14 | davidson
# Processing Record 6 of Set 14 | buqayq
# City not found. Skipping...
# Processing Record 7 of Set 14 | tukrah
# Processing Record 8 of Set 14 | sainte-marie
# Processing Record 9 of Set 14 | gat
# Processing Record 10 of Set 14 | xianyang
# Processing Record 11 of Set 14 | faanui
# Processing Record 12 of Set 14 | dingle
# Processing Record 13 of Set 14 | pevek
# Processing Record 14 of Set 14 | uruzgan
# Processing Record 15 of Set 14 | bathsheba
# Processing Record 16 of Set 14 | hilo
# Processing Record 17 of Set 14 | tessalit
# Processing Record 18 of Set 14 | san patricio
# Processing Record 19 of Set 14 | malinyi
# Processing Record 20 of Set 14 | mehamn
# Processing Record 21 of Set 14 | saint-philippe
# Processing Record 22 of Set 14 | souillac
# Processing Record 23 of Set 14 | aripuana
# Processing Record 24 of Set 14 | yellowknife
# Processing Record 25 of Set 14 | cabo rojo
# Processing Record 26 of Set 14 | torbay
# Processing Record 27 of Set 14 | batemans bay
# Processing Record 28 of Set 14 | geraldton
# Processing Record 29 of Set 14 | attawapiskat
# City not found. Skipping...
# Processing Record 30 of Set 14 | alofi
# Processing Record 31 of Set 14 | sao sebastiao
# Processing Record 32 of Set 14 | barrow
# Processing Record 33 of Set 14 | east london
# Processing Record 34 of Set 14 | avarua
# Processing Record 35 of Set 14 | victoria
# Processing Record 36 of Set 14 | barentsburg
# City not found. Skipping...
# Processing Record 37 of Set 14 | sinjah
# City not found. Skipping...
# Processing Record 38 of Set 14 | grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 14 | praia da vitoria
# Processing Record 40 of Set 14 | mogadishu
# Processing Record 41 of Set 14 | jamestown
# Processing Record 42 of Set 14 | tomatlan
# Processing Record 43 of Set 14 | mys shmidta
# City not found. Skipping...
# Processing Record 44 of Set 14 | saint george
# Processing Record 45 of Set 14 | airai
# Processing Record 46 of Set 14 | beira
# Processing Record 47 of Set 14 | bonthe
# Processing Record 48 of Set 14 | hami
# Processing Record 49 of Set 14 | vaitupu
# City not found. Skipping...
# Processing Record 50 of Set 14 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 1 of Set 15 | lebu
# Processing Record 2 of Set 15 | nabire
# Processing Record 3 of Set 15 | severo-kurilsk
# Processing Record 4 of Set 15 | medzilaborce
# Processing Record 5 of Set 15 | portland
# Processing Record 6 of Set 15 | manaure
# Processing Record 7 of Set 15 | belushya guba
# City not found. Skipping...
# Processing Record 8 of Set 15 | isangel
# Processing Record 9 of Set 15 | deputatskiy
# Processing Record 10 of Set 15 | nikolskoye
# Processing Record 11 of Set 15 | najran
# Processing Record 12 of Set 15 | tsihombe
# City not found. Skipping...
# Processing Record 13 of Set 15 | rawannawi
# City not found. Skipping...
# Processing Record 14 of Set 15 | walvis bay
# Processing Record 15 of Set 15 | tucumcari
# Processing Record 16 of Set 15 | songjianghe
# Processing Record 17 of Set 15 | sitka
# Processing Record 18 of Set 15 | thompson
# Processing Record 19 of Set 15 | yar-sale
# Processing Record 20 of Set 15 | ballina
# Processing Record 21 of Set 15 | cidreira
# Processing Record 22 of Set 15 | celestun
# Processing Record 23 of Set 15 | seydi
# Processing Record 24 of Set 15 | hamilton
# Processing Record 25 of Set 15 | aklavik
# Processing Record 26 of Set 15 | kommunar
# Processing Record 27 of Set 15 | huarmey
# Processing Record 28 of Set 15 | gao
# Processing Record 29 of Set 15 | mezen
# Processing Record 30 of Set 15 | san rafael
# Processing Record 31 of Set 15 | tasiilaq
# Processing Record 32 of Set 15 | kaeo
# Processing Record 33 of Set 15 | tuatapere
# Processing Record 34 of Set 15 | ponta do sol
# Processing Record 35 of Set 15 | tiznit
# Processing Record 36 of Set 15 | timra
# Processing Record 37 of Set 15 | iquitos
# Processing Record 38 of Set 15 | ancud
# Processing Record 39 of Set 15 | singaraja
# Processing Record 40 of Set 15 | chokurdakh
# Processing Record 41 of Set 15 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 15 | ilulissat
# Processing Record 43 of Set 15 | leningradskiy
# Processing Record 44 of Set 15 | herat
# Processing Record 45 of Set 15 | mahebourg
# Processing Record 46 of Set 15 | praya
# Processing Record 47 of Set 15 | mandalgovi
# Processing Record 48 of Set 15 | laguna
# Processing Record 49 of Set 15 | koslan
# Processing Record 50 of Set 15 | alta floresta
# Processing Record 1 of Set 16 | diamantino
# Processing Record 2 of Set 16 | ixtapa
# Processing Record 3 of Set 16 | matale
# Processing Record 4 of Set 16 | saleaula
# City not found. Skipping...
# Processing Record 5 of Set 16 | georgetown
# Processing Record 6 of Set 16 | umm lajj
# Processing Record 7 of Set 16 | cabedelo
# Processing Record 8 of Set 16 | provideniya
# Processing Record 9 of Set 16 | kysyl-syr
# Processing Record 10 of Set 16 | vila franca do campo
# Processing Record 11 of Set 16 | wakkanai
# Processing Record 12 of Set 16 | namibe
# Processing Record 13 of Set 16 | vieux-habitants
# Processing Record 14 of Set 16 | chumikan
# Processing Record 15 of Set 16 | lompoc
# Processing Record 16 of Set 16 | nikolsk
# Processing Record 17 of Set 16 | port lincoln
# Processing Record 18 of Set 16 | ilhabela
# Processing Record 19 of Set 16 | rawson
# Processing Record 20 of Set 16 | north bend
# Processing Record 21 of Set 16 | kyzyl-suu
# Processing Record 22 of Set 16 | upernavik
# Processing Record 23 of Set 16 | bonavista
# Processing Record 24 of Set 16 | mandurah
# Processing Record 25 of Set 16 | iqaluit
# Processing Record 26 of Set 16 | dongsheng
# Processing Record 27 of Set 16 | butaritari
# Processing Record 28 of Set 16 | lander
# Processing Record 29 of Set 16 | amapa
# Processing Record 30 of Set 16 | nivala
# Processing Record 31 of Set 16 | puerto ayora
# Processing Record 32 of Set 16 | lubango
# Processing Record 33 of Set 16 | bastrop
# Processing Record 34 of Set 16 | te anau
# Processing Record 35 of Set 16 | aden
# Processing Record 36 of Set 16 | karaul
# City not found. Skipping...
# Processing Record 37 of Set 16 | solnechnyy
# Processing Record 38 of Set 16 | bredasdorp
# Processing Record 39 of Set 16 | ginir
# Processing Record 40 of Set 16 | itoman
# Processing Record 41 of Set 16 | semey
# Processing Record 42 of Set 16 | constitucion
# Processing Record 43 of Set 16 | saskylakh
# Processing Record 44 of Set 16 | carnarvon
# Processing Record 45 of Set 16 | vardo
# Processing Record 46 of Set 16 | lagoa
# Processing Record 47 of Set 16 | stekolnyy
# City not found. Skipping...
# Processing Record 48 of Set 16 | egvekinot
# Processing Record 49 of Set 16 | coihaique
# Processing Record 50 of Set 16 | santa vitoria do palmar
# Processing Record 1 of Set 17 | san ramon
# Processing Record 2 of Set 17 | kodiak
# Processing Record 3 of Set 17 | tuktoyaktuk
# Processing Record 4 of Set 17 | sola
# Processing Record 5 of Set 17 | high level
# Processing Record 6 of Set 17 | tambacounda
# Processing Record 7 of Set 17 | vaxjo
# Processing Record 8 of Set 17 | fevik
# Processing Record 9 of Set 17 | la ronge
# Processing Record 10 of Set 17 | sorvag
# City not found. Skipping...
# Processing Record 11 of Set 17 | san felipe
# Processing Record 12 of Set 17 | muros
# Processing Record 13 of Set 17 | phan rang
# City not found. Skipping...
# Processing Record 14 of Set 17 | fort-shevchenko
# Processing Record 15 of Set 17 | asyut
# Processing Record 16 of Set 17 | cabo san lucas
# Processing Record 17 of Set 17 | khandyga
# Processing Record 18 of Set 17 | bilibino
# Processing Record 19 of Set 17 | george
# Processing Record 20 of Set 17 | svetlaya
# Processing Record 21 of Set 17 | santomera
# Processing Record 22 of Set 17 | kirkenes
# Processing Record 23 of Set 17 | lethem
# Processing Record 24 of Set 17 | waingapu
# Processing Record 25 of Set 17 | kargasok
# Processing Record 26 of Set 17 | darhan
# Processing Record 27 of Set 17 | bandarbeyla
# Processing Record 28 of Set 17 | mineral wells
# Processing Record 29 of Set 17 | kholm-zhirkovskiy
# Processing Record 30 of Set 17 | barawe
# City not found. Skipping...
# Processing Record 31 of Set 17 | sao joao da barra
# Processing Record 32 of Set 17 | asau
# Processing Record 33 of Set 17 | salalah
# Processing Record 34 of Set 17 | bat khela
# Processing Record 35 of Set 17 | fortuna
# Processing Record 36 of Set 17 | tecolutla
# Processing Record 37 of Set 17 | changqing
# Processing Record 38 of Set 17 | samalaeulu
# City not found. Skipping...
# Processing Record 39 of Set 17 | wladyslawowo
# Processing Record 40 of Set 17 | ruatoria
# City not found. Skipping...
# Processing Record 41 of Set 17 | pachino
# Processing Record 42 of Set 17 | narsaq
# Processing Record 43 of Set 17 | mount gambier
# Processing Record 44 of Set 17 | tarko-sale
# Processing Record 45 of Set 17 | sentyabrskiy
# City not found. Skipping...
# Processing Record 46 of Set 17 | saint-francois
# Processing Record 47 of Set 17 | hobart
# Processing Record 48 of Set 17 | necochea
# Processing Record 49 of Set 17 | sioux lookout
# Processing Record 50 of Set 17 | tiksi
# Processing Record 1 of Set 18 | virginia beach
# Processing Record 2 of Set 18 | sao filipe
# Processing Record 3 of Set 18 | aqtobe
# Processing Record 4 of Set 18 | cherskiy
# Processing Record 5 of Set 18 | osoyoos
# Processing Record 6 of Set 18 | cairns
# Processing Record 7 of Set 18 | boa vista
# Processing Record 8 of Set 18 | morros
# Processing Record 9 of Set 18 | lolua
# City not found. Skipping...
# Processing Record 10 of Set 18 | den helder
# Processing Record 11 of Set 18 | ribeira grande
# Processing Record 12 of Set 18 | marcona
# City not found. Skipping...
# Processing Record 13 of Set 18 | antofagasta
# Processing Record 14 of Set 18 | kidal
# Processing Record 15 of Set 18 | shenjiamen
# Processing Record 16 of Set 18 | zhaotong
# Processing Record 17 of Set 18 | sobolevo
# Processing Record 18 of Set 18 | pinkafeld
# Processing Record 19 of Set 18 | itupiranga
# Processing Record 20 of Set 18 | husavik
# Processing Record 21 of Set 18 | atambua
# Processing Record 22 of Set 18 | ambon
# Processing Record 23 of Set 18 | rosignol
# Processing Record 24 of Set 18 | zyryanka
# Processing Record 25 of Set 18 | caala
# Processing Record 26 of Set 18 | kamennomostskoye
# Processing Record 27 of Set 18 | waddan
# Processing Record 28 of Set 18 | kotri
# Processing Record 29 of Set 18 | marzuq
# Processing Record 30 of Set 18 | kavieng
# Processing Record 31 of Set 18 | tura
# Processing Record 32 of Set 18 | stornoway
# Processing Record 33 of Set 18 | ust-ilimsk
# Processing Record 34 of Set 18 | southbridge
# Processing Record 35 of Set 18 | berlevag
# Processing Record 36 of Set 18 | grand gaube
# Processing Record 37 of Set 18 | castro
# Processing Record 38 of Set 18 | hofn
# Processing Record 39 of Set 18 | saint-augustin
# Processing Record 40 of Set 18 | sangar
# Processing Record 41 of Set 18 | omboue
# Processing Record 42 of Set 18 | broken hill
# Processing Record 43 of Set 18 | labuhan
# Processing Record 44 of Set 18 | arinos
# Processing Record 45 of Set 18 | katsuura
# Processing Record 46 of Set 18 | songea
# Processing Record 47 of Set 18 | kulhudhuffushi
# Processing Record 48 of Set 18 | bac lieu
# Processing Record 49 of Set 18 | port moresby
# Processing Record 50 of Set 18 | bud
# Processing Record 1 of Set 19 | khash
# Processing Record 2 of Set 19 | achacachi
# Processing Record 3 of Set 19 | vestmannaeyjar
# Processing Record 4 of Set 19 | taltal
# Processing Record 5 of Set 19 | westport
# Processing Record 6 of Set 19 | padang
# Processing Record 7 of Set 19 | santa cruz
# Processing Record 8 of Set 19 | road town
# Processing Record 9 of Set 19 | lopsmarka
# Processing Record 10 of Set 19 | beringovskiy
# Processing Record 11 of Set 19 | lvov
# Processing Record 12 of Set 19 | arraial do cabo
# Processing Record 13 of Set 19 | huaicheng
# Processing Record 14 of Set 19 | gold coast
# Processing Record 15 of Set 19 | touros
# Processing Record 16 of Set 19 | esna
# Processing Record 17 of Set 19 | abong mbang
# Processing Record 18 of Set 19 | port macquarie
# Processing Record 19 of Set 19 | zaysan
# Processing Record 20 of Set 19 | abu samrah
# Processing Record 21 of Set 19 | kaura namoda
# Processing Record 22 of Set 19 | yerbogachen
# Processing Record 23 of Set 19 | san quintin
# Processing Record 24 of Set 19 | teshie
# Processing Record 25 of Set 19 | birao
# Processing Record 26 of Set 19 | naze
# Processing Record 27 of Set 19 | menongue
# Processing Record 28 of Set 19 | kaupanger
# Processing Record 29 of Set 19 | mushie
# Processing Record 30 of Set 19 | cavaillon
# Processing Record 31 of Set 19 | coahuayana
# Processing Record 32 of Set 19 | angra
# City not found. Skipping...
# Processing Record 33 of Set 19 | tazovskiy
# Processing Record 34 of Set 19 | bongandanga
# Processing Record 35 of Set 19 | puerto leguizamo
# Processing Record 36 of Set 19 | san cristobal
# Processing Record 37 of Set 19 | novopokrovka
# Processing Record 38 of Set 19 | waipawa
# Processing Record 39 of Set 19 | saint-pierre
# Processing Record 40 of Set 19 | krabi
# Processing Record 41 of Set 19 | palmer
# Processing Record 42 of Set 19 | oleksandrivka
# Processing Record 43 of Set 19 | luorong
# Processing Record 44 of Set 19 | akhalgori
# Processing Record 45 of Set 19 | blonduos
# City not found. Skipping...
# Processing Record 46 of Set 19 | shelabolikha
# Processing Record 47 of Set 19 | bambanglipuro
# Processing Record 48 of Set 19 | thap than
# Processing Record 49 of Set 19 | myaundzha
# Processing Record 50 of Set 19 | yambio
# Processing Record 1 of Set 20 | weinan
# Processing Record 2 of Set 20 | harper
# Processing Record 3 of Set 20 | puerto del rosario
# Processing Record 4 of Set 20 | surt
# Processing Record 5 of Set 20 | mecca
# Processing Record 6 of Set 20 | san antonio
# Processing Record 7 of Set 20 | xuanzhou
# Processing Record 8 of Set 20 | felanitx
# Processing Record 9 of Set 20 | palabuhanratu
# City not found. Skipping...
# Processing Record 10 of Set 20 | polunochnoye
# Processing Record 11 of Set 20 | teya
# Processing Record 12 of Set 20 | dudinka
# Processing Record 13 of Set 20 | iberia
# Processing Record 14 of Set 20 | rocha
# Processing Record 15 of Set 20 | karratha
# Processing Record 16 of Set 20 | redmond
# Processing Record 17 of Set 20 | praia
# Processing Record 18 of Set 20 | chancay
# Processing Record 19 of Set 20 | codrington
# Processing Record 20 of Set 20 | benguela
# Processing Record 21 of Set 20 | samusu
# City not found. Skipping...
# Processing Record 22 of Set 20 | namwala
# Processing Record 23 of Set 20 | koygorodok
# Processing Record 24 of Set 20 | ituacu
# Processing Record 25 of Set 20 | hay river
# Processing Record 26 of Set 20 | villazon
# Processing Record 27 of Set 20 | umzimvubu
# City not found. Skipping...
# Processing Record 28 of Set 20 | micheweni
# Processing Record 29 of Set 20 | quthing
# Processing Record 30 of Set 20 | lima
# Processing Record 31 of Set 20 | luba
# Processing Record 32 of Set 20 | alekseyevka
# Processing Record 33 of Set 20 | qaqortoq
# Processing Record 34 of Set 20 | turukhansk
# Processing Record 35 of Set 20 | shimoda
# Processing Record 36 of Set 20 | umm kaddadah
# Processing Record 37 of Set 20 | pitkyaranta
# Processing Record 38 of Set 20 | ginda
# Processing Record 39 of Set 20 | hihifo
# City not found. Skipping...
# Processing Record 40 of Set 20 | lichuan
# Processing Record 41 of Set 20 | maceio
# Processing Record 42 of Set 20 | puerto el triunfo
# Processing Record 43 of Set 20 | wajima
# Processing Record 44 of Set 20 | vasylivka
# Processing Record 45 of Set 20 | porto torres
# Processing Record 46 of Set 20 | gympie
# Processing Record 47 of Set 20 | ambilobe
# Processing Record 48 of Set 20 | madang
# Processing Record 49 of Set 20 | saldanha
# Processing Record 50 of Set 20 | acapulco
# Processing Record 1 of Set 21 | north platte
# Processing Record 2 of Set 21 | port hardy
# Processing Record 3 of Set 21 | caravelas
# Processing Record 4 of Set 21 | erenhot
# Processing Record 5 of Set 21 | hisor
# Processing Record 6 of Set 21 | port blair
# Processing Record 7 of Set 21 | plaster rock
# Processing Record 8 of Set 21 | aksu
# Processing Record 9 of Set 21 | iisalmi
# Processing Record 10 of Set 21 | bolgatanga
# Processing Record 11 of Set 21 | norman wells
# Processing Record 12 of Set 21 | olafsvik
# Processing Record 13 of Set 21 | meadow lake
# Processing Record 14 of Set 21 | esperance
# Processing Record 15 of Set 21 | havoysund
# Processing Record 16 of Set 21 | baykit
# Processing Record 17 of Set 21 | poum
# Processing Record 18 of Set 21 | shelburne
# Processing Record 19 of Set 21 | vanimo
# Processing Record 20 of Set 21 | almaznyy
# Processing Record 21 of Set 21 | fort nelson
# Processing Record 22 of Set 21 | qasigiannguit
# Processing Record 23 of Set 21 | ahipara
# Processing Record 24 of Set 21 | moose factory
# Processing Record 25 of Set 21 | chuy
# Processing Record 26 of Set 21 | concordia
# Processing Record 27 of Set 21 | college
# Processing Record 28 of Set 21 | huancavelica
# Processing Record 29 of Set 21 | amderma
# City not found. Skipping...
# Processing Record 30 of Set 21 | paamiut
# Processing Record 31 of Set 21 | north myrtle beach
# Processing Record 32 of Set 21 | trincomalee
# Processing Record 33 of Set 21 | nguiu
# City not found. Skipping...
# Processing Record 34 of Set 21 | woodward
# Processing Record 35 of Set 21 | ihiala
# Processing Record 36 of Set 21 | vao
# Processing Record 37 of Set 21 | brenham
# Processing Record 38 of Set 21 | sao domingos
# Processing Record 39 of Set 21 | havelock
# Processing Record 40 of Set 21 | manaus
# Processing Record 41 of Set 21 | kinlochleven
# Processing Record 42 of Set 21 | ijero
# Processing Record 43 of Set 21 | manali
# Processing Record 44 of Set 21 | vila velha
# Processing Record 45 of Set 21 | beloha
# Processing Record 46 of Set 21 | yelanskiy
# Processing Record 47 of Set 21 | kupang
# Processing Record 48 of Set 21 | ust-kuyga
# Processing Record 49 of Set 21 | lorengau
# Processing Record 50 of Set 21 | voznesenye
# Processing Record 1 of Set 22 | awjilah
# Processing Record 2 of Set 22 | sao miguel do araguaia
# Processing Record 3 of Set 22 | karkaralinsk
# City not found. Skipping...
# Processing Record 4 of Set 22 | klaksvik
# Processing Record 5 of Set 22 | kanker
# Processing Record 6 of Set 22 | ust-kut
# Processing Record 7 of Set 22 | la asuncion
# Processing Record 8 of Set 22 | baillif
# Processing Record 9 of Set 22 | byron bay
# Processing Record 10 of Set 22 | nioki
# Processing Record 11 of Set 22 | brae
# Processing Record 12 of Set 22 | port keats
# Processing Record 13 of Set 22 | rundu
# Processing Record 14 of Set 22 | nome
# Processing Record 15 of Set 22 | casino
# Processing Record 16 of Set 22 | tilichiki
# Processing Record 17 of Set 22 | cayeli
# Processing Record 18 of Set 22 | mao
# Processing Record 19 of Set 22 | maumere
# Processing Record 20 of Set 22 | merauke
# Processing Record 21 of Set 22 | kabwe
# Processing Record 22 of Set 22 | bitung
# Processing Record 23 of Set 22 | oistins
# Processing Record 24 of Set 22 | deer lake
# Processing Record 25 of Set 22 | chardara
# Processing Record 26 of Set 22 | emba
# Processing Record 27 of Set 22 | ilabaya
# Processing Record 28 of Set 22 | panama city
# Processing Record 29 of Set 22 | verkhoyansk
# Processing Record 30 of Set 22 | neryungri
# Processing Record 31 of Set 22 | pafos
# Processing Record 32 of Set 22 | nelson bay
# Processing Record 33 of Set 22 | mizdah
# Processing Record 34 of Set 22 | lumby
# Processing Record 35 of Set 22 | unai
# Processing Record 36 of Set 22 | arcachon
# Processing Record 37 of Set 22 | nizhniy odes
# Processing Record 38 of Set 22 | wiwili
# Processing Record 39 of Set 22 | takaka
# Processing Record 40 of Set 22 | athabasca
# Processing Record 41 of Set 22 | nemuro
# Processing Record 42 of Set 22 | yulara
# Processing Record 43 of Set 22 | ierapetra
# Processing Record 44 of Set 22 | nanakuli
# Processing Record 45 of Set 22 | jacqueville
# Processing Record 46 of Set 22 | champerico
# Processing Record 47 of Set 22 | bar harbor
# Processing Record 48 of Set 22 | hualmay
# Processing Record 49 of Set 22 | cayenne
# Processing Record 50 of Set 22 | kiama
# Processing Record 1 of Set 23 | banda aceh
# Processing Record 2 of Set 23 | villarrica
# Processing Record 3 of Set 23 | kailua
# Processing Record 4 of Set 23 | snizhne
# Processing Record 5 of Set 23 | alfenas
# Processing Record 6 of Set 23 | rungata
# City not found. Skipping...
# Processing Record 7 of Set 23 | amalapuram
# Processing Record 8 of Set 23 | eureka
# Processing Record 9 of Set 23 | tommot
# Processing Record 10 of Set 23 | buraydah
# Processing Record 11 of Set 23 | dzhusaly
# City not found. Skipping...
# Processing Record 12 of Set 23 | floro
# Processing Record 13 of Set 23 | ugoofaaru
# Processing Record 14 of Set 23 | comodoro rivadavia
# Processing Record 15 of Set 23 | russell
# Processing Record 16 of Set 23 | itaueira
# Processing Record 17 of Set 23 | seoul
# Processing Record 18 of Set 23 | lazaro cardenas
# Processing Record 19 of Set 23 | richards bay
# Processing Record 20 of Set 23 | fallon
# Processing Record 21 of Set 23 | revin
# Processing Record 22 of Set 23 | la pintada
# Processing Record 23 of Set 23 | mount isa
# Processing Record 24 of Set 23 | gogrial
# Processing Record 25 of Set 23 | oyem
# Processing Record 26 of Set 23 | omsukchan
# Processing Record 27 of Set 23 | ler
# Processing Record 28 of Set 23 | perth
# Processing Record 29 of Set 23 | marsaxlokk
# Processing Record 30 of Set 23 | hovd
# Processing Record 31 of Set 23 | yumen
# Processing Record 32 of Set 23 | batagay
# Processing Record 33 of Set 23 | whyalla
# Processing Record 34 of Set 23 | port-cartier
# Processing Record 35 of Set 23 | nicoya
# Processing Record 36 of Set 23 | uttarkashi
# Processing Record 37 of Set 23 | kungurtug
# Processing Record 38 of Set 23 | portree
# Processing Record 39 of Set 23 | atkarsk
# Processing Record 40 of Set 23 | sembe
# Processing Record 41 of Set 23 | san juan
# Processing Record 42 of Set 23 | gulshat
# City not found. Skipping...
# Processing Record 43 of Set 23 | kavaratti
# Processing Record 44 of Set 23 | mindelo
# Processing Record 45 of Set 23 | isla mujeres
# Processing Record 46 of Set 23 | namatanai
# Processing Record 47 of Set 23 | imeni poliny osipenko
# Processing Record 48 of Set 23 | payo
# Processing Record 49 of Set 23 | ayagoz
# Processing Record 50 of Set 23 | pangai
# Processing Record 1 of Set 24 | porto velho
# Processing Record 2 of Set 24 | ust-karsk
# Processing Record 3 of Set 24 | sinnamary
# Processing Record 4 of Set 24 | medea
# Processing Record 5 of Set 24 | ulkan
# Processing Record 6 of Set 24 | tyrma
# Processing Record 7 of Set 24 | buin
# Processing Record 8 of Set 24 | usinsk
# Processing Record 9 of Set 24 | kamenskoye
# City not found. Skipping...
# Processing Record 10 of Set 24 | tuy hoa
# Processing Record 11 of Set 24 | abatskoye
# Processing Record 12 of Set 24 | bukama
# Processing Record 13 of Set 24 | lavrentiya
# Processing Record 14 of Set 24 | honiara
# Processing Record 15 of Set 24 | areosa
# Processing Record 16 of Set 24 | atar
# Processing Record 17 of Set 24 | davila
# Processing Record 18 of Set 24 | nizhniy kuranakh
# Processing Record 19 of Set 24 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 20 of Set 24 | satitoa
# City not found. Skipping...
# Processing Record 21 of Set 24 | guerrero negro
# Processing Record 22 of Set 24 | kamaishi
# Processing Record 23 of Set 24 | la macarena
# Processing Record 24 of Set 24 | perevoz
# Processing Record 25 of Set 24 | cap malheureux
# Processing Record 26 of Set 24 | mikhaylovka
# Processing Record 27 of Set 24 | cochrane
# Processing Record 28 of Set 24 | samarai
# Processing Record 29 of Set 24 | gumdag
# Processing Record 30 of Set 24 | grindavik
# Processing Record 31 of Set 24 | porangatu
# Processing Record 32 of Set 24 | guane
# Processing Record 33 of Set 24 | yanam
# Processing Record 34 of Set 24 | ferrol
# Processing Record 35 of Set 24 | dunedin
# Processing Record 36 of Set 24 | neuquen
# Processing Record 37 of Set 24 | yukamenskoye
# Processing Record 38 of Set 24 | nago
# Processing Record 39 of Set 24 | pravda
# Processing Record 40 of Set 24 | pagondas
# City not found. Skipping...
# Processing Record 41 of Set 24 | mahibadhoo
# Processing Record 42 of Set 24 | pindi gheb
# Processing Record 43 of Set 24 | acarau
# Processing Record 44 of Set 24 | kawalu
# Processing Record 45 of Set 24 | antsohihy
# Processing Record 46 of Set 24 | haines junction
# Processing Record 47 of Set 24 | baturaja
# Processing Record 48 of Set 24 | anadyr
# Processing Record 49 of Set 24 | nanortalik
# Processing Record 50 of Set 24 | atyrau
# Processing Record 1 of Set 25 | kumluca
# Processing Record 2 of Set 25 | jieshi
# Processing Record 3 of Set 25 | coari
# Processing Record 4 of Set 25 | corby
# Processing Record 5 of Set 25 | storsteinnes
# Processing Record 6 of Set 25 | saint-georges
# Processing Record 7 of Set 25 | cranbrook
# Processing Record 8 of Set 25 | puerto baquerizo moreno
# Processing Record 9 of Set 25 | kutum
# Processing Record 10 of Set 25 | kokopo
# Processing Record 11 of Set 25 | the valley
# Processing Record 12 of Set 25 | verkhoshizhemye
# Processing Record 13 of Set 25 | gribanovskiy
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0          Leeton -34.57  146.40     46.40       100          75        3.36
# 1  Port Elizabeth -33.92   25.57     48.20        66           0        8.05
# 2      Nouadhibou  20.93  -17.03     69.80        83           0       10.29
# 3       Severnoye  56.35   78.36     63.27        88          77        8.12
# 4       Busselton -33.65  115.33     48.99        74           0       16.98
# 5          Sorong  -0.88  131.25     79.16        83         100       11.14
# 6    Kruisfontein -34.00   24.73     44.40        66           0        5.82
# 7          Matara   5.95   80.54     79.07        86         100        8.55
# 8           Kindu  -2.95   25.95     70.18        92          60        1.77
# 9          Albany  42.60  -73.97     78.01        81           0        5.70
#
#   Country  Rain(inches)  Snow(inches) Current Description
# 0      AU          0.00             0       broken clouds
# 1      ZA          0.00             0           clear sky
# 2      MR          0.00             0           clear sky
# 3      RU          0.00             0       broken clouds
# 4      AU          0.00             0           clear sky
# 5      ID          2.03             0       moderate rain
# 6      ZA          0.00             0           clear sky
# 7      LK          0.00             0     overcast clouds
# 8      CD          0.23             0          light rain
# 9      US          0.96             0          light rain

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description", "Rain(inches)", "Snow(inches)"]
city_data_df = city_data_df.reindex(columns = new_column_order)
city_data_df.head(10)
# Out:
#              City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0          Leeton      AU -34.57  146.40     46.40       100          75
# 1  Port Elizabeth      ZA -33.92   25.57     48.20        66           0
# 2      Nouadhibou      MR  20.93  -17.03     69.80        83           0
# 3       Severnoye      RU  56.35   78.36     63.27        88          77
# 4       Busselton      AU -33.65  115.33     48.99        74           0
# 5          Sorong      ID  -0.88  131.25     79.16        83         100
# 6    Kruisfontein      ZA -34.00   24.73     44.40        66           0
# 7          Matara      LK   5.95   80.54     79.07        86         100
# 8           Kindu      CD  -2.95   25.95     70.18        92          60
# 9          Albany      US  42.60  -73.97     78.01        81           0
#
#    Wind Speed Current Description  Rain(inches)  Snow(inches)
# 0        3.36       broken clouds          0.00             0
# 1        8.05           clear sky          0.00             0
# 2       10.29           clear sky          0.00             0
# 3        8.12       broken clouds          0.00             0
# 4       16.98           clear sky          0.00             0
# 5       11.14       moderate rain          2.03             0
# 6        5.82           clear sky          0.00             0
# 7        8.55     overcast clouds          0.00             0
# 8        1.77          light rain          0.23             0
# 9        5.70          light rain          0.96             0

# %%
# Create the output file (CSV).
output_data_file = "weather_data/WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
